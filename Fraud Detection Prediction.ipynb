# %% [markdown]
# # Fraud Detection
#
# # Multiple Regression Analysis on Transaction Data
#
# ## Introduction
#
# The purpose of this project is to perform a multiple regression analysis to understand and predict transaction amounts. Regression analysis explores the relationships between one dependent variable (`TransactionAmount`) and multiple independent variables (e.g., `CustomerAge`, `TransactionDuration`, etc.).
#
# ### Notebook Outline:
# 1. **Data Import and Inspection**
# 2. **Data Preprocessing**
# 3. **Exploratory Data Analysis**
# 4. **Model Building**
# 5. **Results and Interpretation**
# 6. **Conclusion**
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics.regressionplots import plot_partregress_grid
import scipy.stats as stats
from scipy.stats import boxcox

# %% [markdown]
# ## Data Import and Inspection

# %%
fraud_data =pd.read_csv(r"C:\Users\EWURA\Desktop\Fraud Detection\archive (3)\bank_transactions_data_2.csv")
fraud_data
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0         TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1         TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2         TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3         TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4         TX000005   AC00411              13.45  2023-10-16 17:51:24
# ...            ...       ...                ...                  ...
# 2507      TX002508   AC00297             856.21  2023-04-26 17:09:36
# 2508      TX002509   AC00322             251.54  2023-03-22 17:36:48
# 2509      TX002510   AC00095              28.63  2023-08-21 17:08:50
# 2510      TX002511   AC00118             185.97  2023-02-24 16:24:46
# 2511      TX002512   AC00009             243.08  2023-02-14 16:21:23
#
#      TransactionType          Location DeviceID      IP Address MerchantID  \
# ...

# %%
# Inspect the dataset
fraud_data.head()
fraud_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TransactionID            2512 non-null   object
#  1   AccountID                2512 non-null   object
#  2   TransactionAmount        2512 non-null   float64
#  3   TransactionDate          2512 non-null   object
#  4   TransactionType          2512 non-null   object
#  5   Location                 2512 non-null   object
#  6   DeviceID                 2512 non-null   object
#  7   IP Address               2512 non-null   object
#  8   MerchantID               2512 non-null   object
#  9   Channel                  2512 non-null   object
#  10  CustomerAge              2512 non-null   int64
#  11  CustomerOccupation       2512 non-null   object
#  12  TransactionDuration      2512 non-null   int64
#  13  LoginAttempts            2512 non-null   int64
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
fraud_data.describe()
# Out:
#        TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# count        2512.000000  2512.000000          2512.000000    2512.000000
# mean          297.593778    44.673965           119.643312       1.124602
# std           291.946243    17.792198            69.963757       0.602662
# min             0.260000    18.000000            10.000000       1.000000
# 25%            81.885000    27.000000            63.000000       1.000000
# 50%           211.140000    45.000000           112.500000       1.000000
# 75%           414.527500    59.000000           161.000000       1.000000
# max          1919.110000    80.000000           300.000000       5.000000
#
#        AccountBalance
# count     2512.000000
# mean      5114.302966
# std       3900.942499
# min        101.250000
# 25%       1504.370000
# 50%       4735.510000
# 75%       7678.820000
# max      14977.990000

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(fraud_data.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Summary statistics for numerical variables
numerical_columns = ['TransactionAmount', 'CustomerAge', 'TransactionDuration', 
                     'LoginAttempts', 'AccountBalance']

# Frequency counts for categorical variables
categorical_columns = ['TransactionType', 'Location', 'Channel', 'CustomerOccupation']
categorical_summary = {col: fraud_data[col].value_counts() for col in categorical_columns}

# Histograms for numerical variables
for col in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(fraud_data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Pairplot for all numerical variables to explore bivariate distributions
sns.pairplot(fraud_data[numerical_columns], diag_kind="kde")
plt.suptitle("Bivariate Distributions of Numerical Variables", y=1.02)
plt.show()

# Individual scatterplots for each pair of numerical variables
for i, col1 in enumerate(numerical_columns):
    for col2 in numerical_columns[i + 1:]:
        plt.figure(figsize=(8, 5))
        sns.scatterplot(x=fraud_data[col1], y=fraud_data[col2], alpha=0.6)
        plt.title(f"Scatterplot of {col1} vs {col2}")
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()

# %%
# Heatmap of numerical variables grouped by TransactionType
plt.figure(figsize=(12, 8))
sns.heatmap(fraud_data.groupby('TransactionType')[numerical_columns].mean().transpose(), annot=True, cmap='coolwarm')
plt.title('Average Numerical Features by TransactionType')
plt.ylabel('Features')
plt.xlabel('TransactionType')
plt.show()

# Pairplot with hue for a categorical variable (e.g., Channel)
sns.pairplot(fraud_data, vars=numerical_columns, hue='Channel', diag_kind="kde", palette="Set2", height=2)
plt.suptitle("Multivariate Analysis: Pairplot Grouped by Channel", y=1.02)
plt.show()

# Boxplot of TransactionAmount across multiple categorical variables
plt.figure(figsize=(12, 6))
sns.boxplot(data=fraud_data, x='Channel', y='TransactionAmount', hue='TransactionType')
plt.title("Transaction Amount by Channel and Transaction Type")
plt.xlabel("Channel")
plt.ylabel("Transaction Amount")
plt.legend(title='TransactionType')
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
